# %% [markdown]
# # Classification testing notebook

# %% [markdown]
# ## Set up

# %%
import os
import logging
import matplotlib.pyplot as plt
import networkx as nx
from typing import Dict, List, Any
import sys
from dotenv import load_dotenv


sys.path.append(os.path.abspath(".."))


from classification.concept_minor_classifier import ConceptMinorClassifier

load_dotenv()


# Configure logging
logging.basicConfig(level=logging.INFO, 
                   format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# %%
graph_comparator = ConceptMinorClassifier(
    neo4j_dsn=os.getenv("NEO4J_DSN"),
    neo4j_user=os.getenv("NEO4J_USER"),
    neo4j_pass=os.getenv("NEO4J_PASSWORD"),
    max_workers=10,
    use_multithreading=False,
)

# %%
image_id = "bcd7deeb-40e6-44db-a36b-d88f4492fff6"
results = graph_comparator.classify(image_id)
graph_comparator.close()
results
# Out:
# INFO:root:Classifying image bcd7deeb-40e6-44db-a36b-d88f4492fff6 using concept minor approach
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property vectors_count does not match: {'min': 5, 'max': 7, 'type': 'range', 'center': 5.995960457042884} != 8 for concept 7_2
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property vectors_count does not match: {'min': 2, 'max': 7, 'type': 'range', 'center': 3.999095991220453} != 8 for concept 1_1
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property vectors_count does not match: {'min': 4, 'max': 5, 'type': 'range', 'center': 4.496068411105842} != 8 for concept 4_3
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property vectors_count does not match: {'min': 4, 'max': 7, 'type': 'range', 'center': 4.501106074020994} != 8 for concept 2_4
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property vectors_count does not match: {'min': 3, 'max': 6, 'type': 'range', 'center': 3.500099074439536} != 8 for concept 7_3
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property corner_points_count does not match: {'min': 0, 'max': 2, 'type': 'range', 'center': 1.4980054972618662} != 3 for concept 5_3
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.4, 'type': 'range', 'center': -0.547079505435661} != 0.7 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.5, 'max': 0.2, 'type': 'range', 'center': 0.047631651812773075} != 0.3 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.4, 'type': 'range', 'center': -0.547079505435661} != 0.6 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.4, 'type': 'range', 'center': -0.547079505435661} != 0.6 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'IntersectionPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.5, 'type': 'range', 'center': -0.4481120057738155} != 0.7 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.5, 'max': 0.2, 'type': 'range', 'center': 0.04612146262917473} != 0.3 for concept 5_1
# INFO:property_handlers.property_matcher_manager:No key angle in classified image node {'labels': ['Point', 'EndPoint'], 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'left'], 'cycle_count': 0, 'vectors_count': 8, 'contour_type': 'OPEN', 'image_id': 'bcd7deeb-40e6-44db-a36b-d88f4492fff6', 'id': '981bed5c-4780-40c7-8d2e-e8459b325ff1', 'normalized_x': -0.4, 'relative_distance': 0.5, 'normalized_y': 0.5, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 3, 'quadrant_change_count': 5, 'y': 75.55091936023972, 'x': 29.4661664634455} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.5, 'type': 'range', 'center': -0.4481120057738155} != 0.7 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.5, 'max': 0.2, 'type': 'range', 'center': 0.04612146262917473} != 0.3 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:No key angle in classified image node {'labels': ['Point', 'EndPoint'], 'session_id': 'test', 'endpoints_count': 2, 'segments': ['center_horizontal', 'center_vertical'], 'cycle_count': 0, 'vectors_count': 8, 'contour_type': 'OPEN', 'image_id': 'bcd7deeb-40e6-44db-a36b-d88f4492fff6', 'id': '86183fdf-9381-4e90-8fda-f4dcabda998c', 'normalized_x': -0.1, 'relative_distance': 0.1, 'normalized_y': 0.0, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 3, 'quadrant_change_count': 5, 'y': 51.000000000000014, 'x': 45.237635209784294} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'IntersectionPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.5, 'type': 'range', 'center': -0.34813350916443025} != 0.7 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.5, 'type': 'range', 'center': -0.34813350916443025} != 0.6 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.1, 'max': 0.5, 'type': 'range', 'center': 0.24985423372248375} != 0.0 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.5, 'type': 'range', 'center': -0.34813350916443025} != 0.6 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.5, 'type': 'range', 'center': -0.248245063376403} != 0.7 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': 0.5, 'type': 'range', 'center': -0.248245063376403} != 0.7 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'IntersectionPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.15054854409662619} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.6, 'max': 0.5, 'type': 'range', 'center': -0.14858388198645964} != 0.6 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property angle_with_ox does not match: {'min': 0, 'max': 150, 'type': 'range', 'center': 50.00010687532815} != 180 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.15054854409662619} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.15076792544595308} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.15076792544595308} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.6, 'max': 0.4, 'type': 'range', 'center': -0.04961792830236185} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.15076792544595308} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.19876484450917092} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.4, 'max': 0.5, 'type': 'range', 'center': -0.04890359066099441} != 0.6 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property angle_with_ox does not match: {'min': 0, 'max': 160, 'type': 'range', 'center': 40.00061102656631} != 180 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.19876484450917092} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.24843138491597386} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.3, 'max': 0.5, 'type': 'range', 'center': 0.2979747539162558} != -0.4 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.3, 'max': 0.5, 'type': 'range', 'center': 0.2979747539162558} != -0.4 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.24856989792673026} != 0.5 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.3, 'max': 0.5, 'type': 'range', 'center': 0.1498025079961404} != 0.6 for concept 5_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.24856989792673026} != 0.5 for concept 5_1
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property endpoints_count does not match: {'min': 3, 'max': 4, 'type': 'range', 'center': 3.4962166800628327} != 2 for concept 4_2
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property corner_points_count does not match: {'min': 0, 'max': 1, 'type': 'range', 'center': 0.4966677266942086} != 3 for concept 1_2
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 3_3
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 3_3
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': -0.0, 'type': 'range', 'center': -0.3016342652714543} != 0.7 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property quadrant does not match: {'min': 3, 'max': 4, 'type': 'range', 'center': 3.4997012575276463} != 1 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property quadrant does not match: {'min': 3, 'max': 4, 'type': 'range', 'center': 3.4997012575276463} != 2 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.2, 'max': 0.6, 'type': 'range', 'center': 0.4493621161205949} != 0.0 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.7, 'max': -0.0, 'type': 'range', 'center': -0.3016342652714543} != 0.6 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property quadrant does not match: {'min': 3, 'max': 4, 'type': 'range', 'center': 3.4997012575276463} != 1 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property angle_with_ox does not match: {'min': 60, 'max': 140, 'type': 'range', 'center': 124.99510843430689} != 20 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'IntersectionPoint', 'Point'} for concept 3_3
# INFO:property_handlers.property_matcher_manager:Property quadrant does not match: {'min': 3, 'max': 4, 'type': 'range', 'center': 3.4997012575276463} != 2 for concept 3_3
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 3_3
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property vectors_count does not match: {'min': 1, 'max': 5, 'type': 'range', 'center': 1.9973552170516509} != 8 for concept 1_3
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property endpoints_count does not match: 0 != 2 for concept 6_2
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property corner_points_count does not match: {'min': 0, 'max': 2, 'type': 'range', 'center': 0.5006238250657714} != 3 for concept 5_2
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property vectors_count does not match: {'min': 2, 'max': 5, 'type': 'range', 'center': 2.9990349840597297} != 8 for concept 7_1
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# ...
# INFO:property_handlers.property_matcher_manager:Property quadrant does not match: 4 != 1 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'IntersectionPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property quadrant does not match: 4 != 2 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.3, 'max': 0.4, 'type': 'range', 'center': -0.09778555752578295} != -0.4 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.5, 'max': -0.1, 'type': 'range', 'center': -0.2514355308244845} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:No key angle in classified image node {'labels': ['Point', 'EndPoint'], 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'left'], 'cycle_count': 0, 'vectors_count': 8, 'contour_type': 'OPEN', 'image_id': 'bcd7deeb-40e6-44db-a36b-d88f4492fff6', 'id': '981bed5c-4780-40c7-8d2e-e8459b325ff1', 'normalized_x': -0.4, 'relative_distance': 0.5, 'normalized_y': 0.5, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 3, 'quadrant_change_count': 5, 'y': 75.55091936023972, 'x': 29.4661664634455} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.1, 'max': 0.4, 'type': 'range', 'center': 0.24987674833481505} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.5, 'max': -0.1, 'type': 'range', 'center': -0.2514355308244845} != 0.0 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:No key angle in classified image node {'labels': ['Point', 'EndPoint'], 'session_id': 'test', 'endpoints_count': 2, 'segments': ['center_horizontal', 'center_vertical'], 'cycle_count': 0, 'vectors_count': 8, 'contour_type': 'OPEN', 'image_id': 'bcd7deeb-40e6-44db-a36b-d88f4492fff6', 'id': '86183fdf-9381-4e90-8fda-f4dcabda998c', 'normalized_x': -0.1, 'relative_distance': 0.1, 'normalized_y': 0.0, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 3, 'quadrant_change_count': 5, 'y': 51.000000000000014, 'x': 45.237635209784294} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'IntersectionPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.1, 'max': 0.4, 'type': 'range', 'center': 0.1531215693603484} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property angle_with_ox does not match: {'min': 0, 'max': 80, 'type': 'range', 'center': 25.001814152938923} != 120 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.5, 'max': 0.0, 'type': 'range', 'center': -0.24991691103266386} != 0.6 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.1, 'max': 0.4, 'type': 'range', 'center': 0.1531215693603484} != 0.0 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.3, 'max': 0.5, 'type': 'range', 'center': -0.04768705197492438} != -0.4 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.5, 'max': 0.0, 'type': 'range', 'center': -0.24991691103266386} != 0.2 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.1526705355722978} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.2, 'max': 0.5, 'type': 'range', 'center': 0.15028392758232115} != -0.4 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.5, 'max': 0.2, 'type': 'range', 'center': -0.19990672880649057} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.2, 'max': 0.5, 'type': 'range', 'center': 0.15028392758232115} != -0.4 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'IntersectionPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.3, 'type': 'range', 'center': 0.15003777040265343} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.3, 'type': 'range', 'center': 0.15003777040265343} != 0.4 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property angle_with_ox does not match: {'min': 10, 'max': 150, 'type': 'range', 'center': 85.00195175875484} != 180 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.2, 'max': 0.4, 'type': 'range', 'center': 0.1488082324051285} != -0.4 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.2493473700471426} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.3, 'max': 0.4, 'type': 'range', 'center': 0.09837107415762537} != -0.4 for concept 2_1
# INFO:property_handlers.property_matcher_manager:No key angle in classified image node {'labels': ['Point', 'EndPoint'], 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'left'], 'cycle_count': 0, 'vectors_count': 8, 'contour_type': 'OPEN', 'image_id': 'bcd7deeb-40e6-44db-a36b-d88f4492fff6', 'id': '981bed5c-4780-40c7-8d2e-e8459b325ff1', 'normalized_x': -0.4, 'relative_distance': 0.5, 'normalized_y': 0.5, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 3, 'quadrant_change_count': 5, 'y': 75.55091936023972, 'x': 29.4661664634455} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'HorizontalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:No key angle in classified image node {'labels': ['Point', 'EndPoint'], 'session_id': 'test', 'endpoints_count': 2, 'segments': ['center_horizontal', 'center_vertical'], 'cycle_count': 0, 'vectors_count': 8, 'contour_type': 'OPEN', 'image_id': 'bcd7deeb-40e6-44db-a36b-d88f4492fff6', 'id': '86183fdf-9381-4e90-8fda-f4dcabda998c', 'normalized_x': -0.1, 'relative_distance': 0.1, 'normalized_y': 0.0, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 3, 'quadrant_change_count': 5, 'y': 51.000000000000014, 'x': 45.237635209784294} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Point'} are not a subset of instance labels {'Vector', 'VerticalVector'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'CornerPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property relative_distance does not match: {'min': 0.0, 'max': 0.4, 'type': 'range', 'center': 0.20003507909380483} != 0.5 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_y does not match: {'min': -0.5, 'max': 0.5, 'type': 'range', 'center': 0.24950346449018013} != 0.6 for concept 2_1
# INFO:property_handlers.property_matcher_manager:Concept labels {'Vector'} are not a subset of instance labels {'EndPoint', 'Point'} for concept 2_1
# INFO:property_handlers.property_matcher_manager:Property normalized_x does not match: {'min': -0.3, 'max': 0.3, 'type': 'range', 'center': -0.0001266754780033048} != -0.4 for concept 2_1
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:property_handlers.property_matcher_manager:Property corner_points_count does not match: {'min': 0, 'max': 2, 'type': 'range', 'center': 1.4980558759567222} != 3 for concept 3_2
# INFO:root:Scores for concept 5_1 and image bcd7deeb-40e6-44db-a36b-d88f4492fff6:
# Structural: 0.6923, Complexity: 1.0000, Specificity: 1.0000, Combined: 0.6923
# INFO:root:Scores for concept 2_1 and image bcd7deeb-40e6-44db-a36b-d88f4492fff6:
# Structural: 1.0000, Complexity: 0.0000, Specificity: 0.0000, Combined: 1.0000
# [{'concept_id': '2_1',
#   'concept_name': '2_1',
#   'session_id': '2_1',
#   'raw_structural_score': 1.0,
#   'is_minor': True,
#   'mapping_size': 9,
#   'concept_size': 9,
#   'image_size': 17,
#   'contractions_count': 0,
#   'comparison_message': 'Concept 2_1 is a minor of the image graph with a complete matching of 9 nodes',
#   'concept_complexity': 17,
#   'specificity': 0.5294117647058824,
#   'normalized_complexity': 0.0,
#   'normalized_specificity': 0.0,
#   'combined_score': 1.0,
#   'activation_level': 1.0},
#  {'concept_id': '5_1',
#   'concept_name': '5_1',
#   'session_id': '5_1',
#   'raw_structural_score': 0.6923076923076923,
#   'is_minor': False,
#   'mapping_size': 9,
#   'concept_size': 13,
#   'image_size': 17,
#   'contractions_count': 0,
#   'comparison_message': 'Partial matching for concept 5_1 with 9/13 nodes matched (69.23%)',
#   'concept_complexity': 25,
#   'specificity': 0.7647058823529411,
#   'normalized_complexity': 1.0,
#   'normalized_specificity': 1.0,
#   'combined_score': 0.6923076923076923,
#   'activation_level': 0.6923076923076923}]
