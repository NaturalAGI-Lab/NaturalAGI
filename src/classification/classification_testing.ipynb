# %% [markdown]
# # Classification testing notebook

# %%
import os
import logging
import sys
from dotenv import load_dotenv


sys.path.append(os.path.abspath(".."))


from classification.concept_minor_classifier import ConceptMinorClassifier
from classification.models import ClassificationResult
from classification.repository.concept_repository import ConceptRepository
from classification.repository.image_repository import ImageRepository

load_dotenv()


# Configure logging
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# %%
image_repository = ImageRepository(
    neo4j_dsn=os.getenv("NEO4J_DSN"),
    neo4j_user=os.getenv("NEO4J_USER"),
    neo4j_pass=os.getenv("NEO4J_PASSWORD"),
)

concept_repository = ConceptRepository(
    neo4j_dsn=os.getenv("NEO4J_DSN"),
    neo4j_user=os.getenv("NEO4J_USER"),
    neo4j_pass=os.getenv("NEO4J_PASSWORD"),
)

graph_comparator = ConceptMinorClassifier(
    concept_repository,
    image_repository,
    max_workers=10,
    use_multithreading=False,
)

# %%
image_id = "5dbefe3b-ff08-4335-a98d-afdc0aa85e23"
results = graph_comparator.classify(image_id)
image_repository.close()
concept_repository.close()
print("\n".join([str(result) for result in results]))
# Out:
# INFO:root:Classifying image 5dbefe3b-ff08-4335-a98d-afdc0aa85e23 using concept minor approach
# INFO:root:Checking concept 1_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [0.2086004  0.89051279]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:18011', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18013', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18015', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18017']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:18011', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18013', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18015', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18017']
# WARNING:root:Preprocessing failed for concept 1_1: Concept has more endpoints than image.
# Traceback (most recent call last):
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/concept_minor_classifier.py", line 158, in _check_single_concept
#     self.critical_point_preprocessor.preprocess_graphs(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 76, in preprocess_graphs
#     inference_graph, concept_graph = self._reduce_graphs_for_isomorphism(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 114, in _reduce_graphs_for_isomorphism
#     inference_graph, concept_graph = self.endpoint_reduction_strategy.reduce(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/reduction_strategy/endpoint_strategy.py", line 89, in reduce
#     raise ValueError("Concept has more endpoints than image.")
# ValueError: Concept has more endpoints than image.
# INFO:root:Checking concept 1_3 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [ 0.60226202 -0.79791201]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:18018', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18020']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:18018', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:18020']
# INFO:reduction_strategy.endpoint_strategy:Concept and image have the same number of endpoints. No reduction needed.
# INFO:reduction_strategy.intersection_strategy:Concept or image has no intersection points.
# INFO:reduction_strategy.corner_point_reduction_strategy:No corner points found in concept graph. Reducing all corner points in image graph.
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, stopping
# INFO:root:Comparing graph with concept 1_3 using Graph Edit Distance
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 9.0
# INFO:root:GED: 9.0, max_possible_ged: 12, similarity: 0.25
# INFO:root:Similarity between image and concept 1_3: 0.25
# INFO:root:Checking concept 2_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [-0.559976   -0.59534474]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:20509', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20511', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20513', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20515']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:20509', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20511', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20513', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20515']
# INFO:reduction_strategy.endpoint_strategy:Concept and image have the same number of endpoints. No reduction needed.
# INFO:reduction_strategy.intersection_strategy:Concept or image has no intersection points.
# INFO:reduction_strategy.corner_point_reduction_strategy:Starting subpath-based corner point reduction
# INFO:services.synced_traversal_service:Starting traversal with initial path 0
# INFO:services.synced_traversal_service:Start nodes: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20509, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20509, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397 from path 0
# INFO:services.synced_traversal_service:Next critical points: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20515, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393
# DEBUG:services.synced_traversal_service:Added segment frozenset({('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20509', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20515', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393')}) to processed set.
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20515, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393 from path 0
# INFO:services.synced_traversal_service:No next critical points found for this path, continuing
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing subpath: [('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20509', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20515', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393')]
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing segment between: (4:d56c147a-80b2-46b4-92e6-1cb28f476107:20509,4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397) and (4:d56c147a-80b2-46b4-92e6-1cb28f476107:20515,4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393)
# INFO:reduction_strategy.corner_point_reduction_strategy:Best path pair found with score 0.723
# INFO:reduction_strategy.corner_point_reduction_strategy:Corner points in subpath: concept=2, image=3
# INFO:reduction_strategy.corner_point_reduction_strategy:Removing 1 corner points from image graph in subpath
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, stopping
# INFO:root:Comparing graph with concept 2_1 using Graph Edit Distance
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 9.0
# INFO:root:GED: 9.0, max_possible_ged: 16, similarity: 0.4375
# INFO:root:Similarity between image and concept 2_1: 0.4375
# INFO:root:Checking concept 2_2 for minor of image
# INFO:root:Concept 2_2 is too complex to be a minor of the image
# INFO:root:Checking concept 3_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [-0.22211316  0.59719473]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, no reductions needed
# INFO:root:Comparing graph with concept 3_1 using Graph Edit Distance
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 9.0
# INFO:root:GED: 9.0, max_possible_ged: 18, similarity: 0.5
# INFO:root:Similarity between image and concept 3_1: 0.5
# INFO:root:Checking concept 6_1 for minor of image
# INFO:root:Concept 6_1 is too complex to be a minor of the image
# INFO:root:Checking concept 7_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [-0.1695424   0.86720589]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:20545', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20547', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20549']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:20545', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20547', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20549']
# INFO:reduction_strategy.endpoint_strategy:Concept and image have the same number of endpoints. No reduction needed.
# INFO:reduction_strategy.intersection_strategy:Concept or image has no intersection points.
# INFO:reduction_strategy.corner_point_reduction_strategy:Starting subpath-based corner point reduction
# INFO:services.synced_traversal_service:Starting traversal with initial path 0
# INFO:services.synced_traversal_service:Start nodes: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20545, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20545, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393 from path 0
# INFO:services.synced_traversal_service:Next critical points: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20549, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397
# DEBUG:services.synced_traversal_service:Added segment frozenset({('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20545', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20549', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397')}) to processed set.
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:20549, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397 from path 0
# INFO:services.synced_traversal_service:No next critical points found for this path, continuing
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing subpath: [('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20545', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:20549', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397')]
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing segment between: (4:d56c147a-80b2-46b4-92e6-1cb28f476107:20545,4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393) and (4:d56c147a-80b2-46b4-92e6-1cb28f476107:20549,4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397)
# INFO:reduction_strategy.corner_point_reduction_strategy:Best path pair found with score 0.837
# INFO:reduction_strategy.corner_point_reduction_strategy:Corner points in subpath: concept=1, image=3
# INFO:reduction_strategy.corner_point_reduction_strategy:Removing 2 corner points from image graph in subpath
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, stopping
# INFO:root:Comparing graph with concept 7_1 using Graph Edit Distance
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# WARNING:graph_similarity.cost_functions:Property segments is not present in the node data of image
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 9.0
# INFO:root:GED: 9.0, max_possible_ged: 14, similarity: 0.3571428571428571
# INFO:root:Similarity between image and concept 7_1: 0.3571428571428571
# INFO:root:Checking concept 9_2 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [0.07044134 0.84468163]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:20550', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20552', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20554', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20556']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:12393', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12394', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12395', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12396', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:20550', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20552', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20554', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:20556']
# INFO:reduction_strategy.endpoint_strategy:Concept has no endpoints. Reducing all endpoints in image.
# INFO:reduction_strategy.endpoint_strategy:Removing 2 nodes from graph. Nodes: {'4:d56c147a-80b2-46b4-92e6-1cb28f476107:12397', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:19612'}
# INFO:reduction_strategy.endpoint_strategy:Graph after reduction: 7 nodes, 6 edges
# WARNING:root:Preprocessing failed for concept 9_2: Concept has intersection points but image does not.
# Traceback (most recent call last):
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/concept_minor_classifier.py", line 158, in _check_single_concept
#     self.critical_point_preprocessor.preprocess_graphs(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 76, in preprocess_graphs
#     inference_graph, concept_graph = self._reduce_graphs_for_isomorphism(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 121, in _reduce_graphs_for_isomorphism
#     self.intersection_reduction_strategy.reduce(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/reduction_strategy/intersection_strategy.py", line 50, in reduce
#     raise ValueError("Concept has intersection points but image does not.")
# ValueError: Concept has intersection points but image does not.
# ClassificationResult(concept_id='3_1', is_minor=True, message='Similarity between image and concept 3_1: 0.5', similarity=0.5)
# ClassificationResult(concept_id='2_1', is_minor=True, message='Similarity between image and concept 2_1: 0.4375', similarity=0.4375)
# ClassificationResult(concept_id='7_1', is_minor=True, message='Similarity between image and concept 7_1: 0.3571428571428571', similarity=0.3571428571428571)
# ClassificationResult(concept_id='1_3', is_minor=True, message='Similarity between image and concept 1_3: 0.25', similarity=0.25)
