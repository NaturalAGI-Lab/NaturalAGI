# %% [markdown]
# # Classification testing notebook

# %%
import os
import logging
import sys
from dotenv import load_dotenv


sys.path.append(os.path.abspath(".."))


from classification.classification_orchestrator import ClassificationOrchestrator

load_dotenv()


# Configure logging
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# %%
neo4j_dsn=os.getenv("NEO4J_DSN")
neo4j_user=os.getenv("NEO4J_USER")
neo4j_pass=os.getenv("NEO4J_PASSWORD")

orchestrator = ClassificationOrchestrator(
    neo4j_dsn=neo4j_dsn,
    neo4j_user=neo4j_user,
    neo4j_pass=neo4j_pass,
    ged_timeout=60,
    use_multiprocessing=False
)
# Out:
# INFO:root:Detected 10 CPUs, using 8 workers
# INFO:root:ClassificationOrchestrator initialized with 8 workers

# %%
image_id = "b5f41e0c-6e24-4692-b457-eca6a554873e"
results = orchestrator.classify_image(image_id)
print("\n".join([str(result) for result in results]))
# Out:
# INFO:root:Starting classification orchestration for image b5f41e0c-6e24-4692-b457-eca6a554873e
# INFO:common.decorator:⏱ get_all_concept_ids took 11.518 ms (avg of 1 run)
# INFO:common.decorator:⏱ get_image_graph took 13.944 ms (avg of 1 run)
# INFO:root:Found 8 concepts to process
# INFO:root:Processing concepts sequentially
# INFO:root:Checking concept 7_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [-0.33       -0.67333333]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:1351', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:1353', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:1355']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:1351', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:1353', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:1355']
# INFO:reduction_strategy.endpoint_strategy:Excess endpoints to remove (1): ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242']
# INFO:reduction_strategy.endpoint_strategy:Removing 2 nodes from graph. Nodes: {'4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15247'}
# INFO:reduction_strategy.endpoint_strategy:Graph after reduction: 7 nodes, 6 edges
# INFO:reduction_strategy.intersection_strategy:Removing IntersectionPoint label from 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243 with degree 2
# INFO:reduction_strategy.intersection_strategy:Adding CornerPoint label to 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243 with degree 2
# INFO:reduction_strategy.intersection_strategy:Concept or image has no intersection points.
# INFO:reduction_strategy.corner_point_reduction_strategy:Starting subpath-based corner point reduction
# INFO:services.synced_traversal_service:Starting traversal with initial path 0
# INFO:services.synced_traversal_service:Start nodes: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:1351, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:1351, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244 from path 0
# INFO:services.synced_traversal_service:Next critical points: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:1355, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246
# DEBUG:services.synced_traversal_service:Added segment frozenset({('4:d56c147a-80b2-46b4-92e6-1cb28f476107:1351', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:1355', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246')}) to processed set.
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:1355, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246 from path 0
# INFO:services.synced_traversal_service:No next critical points found for this path, continuing
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing subpath: [('4:d56c147a-80b2-46b4-92e6-1cb28f476107:1351', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:1355', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246')]
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing segment between: (4:d56c147a-80b2-46b4-92e6-1cb28f476107:1351,4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244) and (4:d56c147a-80b2-46b4-92e6-1cb28f476107:1355,4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246)
# INFO:reduction_strategy.corner_point_reduction_strategy:Best path pair found with score 0.706
# INFO:reduction_strategy.corner_point_reduction_strategy:Corner points in subpath: concept=1, image=2
# INFO:reduction_strategy.corner_point_reduction_strategy:Removing 1 corner points from image graph in subpath
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, stopping
# INFO:root:Comparing graph with concept 7_1 using Graph Edit Distance
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 1.9333333333333333
# INFO:root:GED: 1.9333333333333333, max_possible_ged: 14, similarity: 0.86
# INFO:root:Similarity between image and concept 7_1: 0.86
# INFO:common.decorator:⏱ check_single_concept took 314.332 ms (avg of 1 run)
# INFO:root:Checking concept 1_3 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [ 0.30333333 -0.85333333]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16434', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16436']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16434', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16436']
# INFO:reduction_strategy.endpoint_strategy:Excess endpoints to remove (1): ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244']
# INFO:reduction_strategy.endpoint_strategy:Removing 2 nodes from graph. Nodes: {'4:d56c147a-80b2-46b4-92e6-1cb28f476107:15250', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244'}
# INFO:reduction_strategy.endpoint_strategy:Graph after reduction: 7 nodes, 6 edges
# INFO:reduction_strategy.intersection_strategy:Concept has no intersection points. Removing intersection points from image.
# INFO:reduction_strategy.intersection_strategy:Removing 2 nodes from graph.
# INFO:reduction_strategy.intersection_strategy:Graph after reduction has 5 nodes.
# INFO:reduction_strategy.corner_point_reduction_strategy:No corner points found in concept graph. Reducing all corner points in image graph.
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, stopping
# INFO:root:Comparing graph with concept 1_3 using Graph Edit Distance
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 2.7481481481481485
# INFO:root:GED: 2.7481481481481485, max_possible_ged: 12, similarity: 0.77
# INFO:root:Similarity between image and concept 1_3: 0.77
# INFO:common.decorator:⏱ check_single_concept took 28.286 ms (avg of 1 run)
# INFO:root:Checking concept 2_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [-0.49333333 -0.58      ]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16437', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16439', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16441', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16443']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16437', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16439', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16441', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16443']
# INFO:reduction_strategy.endpoint_strategy:Excess endpoints to remove (1): ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242']
# INFO:reduction_strategy.endpoint_strategy:Removing 2 nodes from graph. Nodes: {'4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15247'}
# INFO:reduction_strategy.endpoint_strategy:Graph after reduction: 7 nodes, 6 edges
# INFO:reduction_strategy.intersection_strategy:Removing IntersectionPoint label from 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243 with degree 2
# INFO:reduction_strategy.intersection_strategy:Adding CornerPoint label to 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243 with degree 2
# INFO:reduction_strategy.intersection_strategy:Concept or image has no intersection points.
# INFO:reduction_strategy.corner_point_reduction_strategy:Starting subpath-based corner point reduction
# INFO:services.synced_traversal_service:Starting traversal with initial path 0
# INFO:services.synced_traversal_service:Start nodes: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16437, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16437, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244 from path 0
# INFO:services.synced_traversal_service:Next critical points: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16443, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246
# DEBUG:services.synced_traversal_service:Added segment frozenset({('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16443', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16437', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244')}) to processed set.
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16443, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246 from path 0
# INFO:services.synced_traversal_service:No next critical points found for this path, continuing
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing subpath: [('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16437', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16443', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246')]
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing segment between: (4:d56c147a-80b2-46b4-92e6-1cb28f476107:16437,4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244) and (4:d56c147a-80b2-46b4-92e6-1cb28f476107:16443,4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246)
# INFO:reduction_strategy.corner_point_reduction_strategy:Best path pair found with score 0.616
# INFO:reduction_strategy.corner_point_reduction_strategy:Corner points in subpath: concept=2, image=2
# INFO:reduction_strategy.corner_point_reduction_strategy:Concept and image have the same number of corner points in this subpath. No reduction needed.
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, stopping
# INFO:root:Comparing graph with concept 2_1 using Graph Edit Distance
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 3.8212096923879564
# INFO:root:GED: 3.8212096923879564, max_possible_ged: 16, similarity: 0.76
# INFO:root:Similarity between image and concept 2_1: 0.76
# INFO:common.decorator:⏱ check_single_concept took 306.604 ms (avg of 1 run)
# INFO:root:Checking concept 2_2 for minor of image
# INFO:root:Concept 2_2 is too complex to be a minor of the image
# INFO:common.decorator:⏱ check_single_concept took 7.892 ms (avg of 1 run)
# INFO:root:Checking concept 3_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [-0.28        0.64666667]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16456', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16458', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16460', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16462', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16464']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16456', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16458', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16460', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16462', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16464']
# INFO:reduction_strategy.endpoint_strategy:Excess endpoints to remove (1): ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244']
# INFO:reduction_strategy.endpoint_strategy:Removing 2 nodes from graph. Nodes: {'4:d56c147a-80b2-46b4-92e6-1cb28f476107:15250', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244'}
# INFO:reduction_strategy.endpoint_strategy:Graph after reduction: 7 nodes, 6 edges
# INFO:reduction_strategy.intersection_strategy:Concept has no intersection points. Removing intersection points from image.
# INFO:reduction_strategy.intersection_strategy:Removing 2 nodes from graph.
# INFO:reduction_strategy.intersection_strategy:Graph after reduction has 5 nodes.
# INFO:reduction_strategy.corner_point_reduction_strategy:Starting subpath-based corner point reduction
# INFO:services.synced_traversal_service:Starting traversal with initial path 0
# INFO:services.synced_traversal_service:Start nodes: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16456, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16456, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246 from path 0
# INFO:services.synced_traversal_service:Next critical points: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16464, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242
# DEBUG:services.synced_traversal_service:Added segment frozenset({('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16456', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16464', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242')}) to processed set.
# INFO:services.synced_traversal_service:Processing node 4:d56c147a-80b2-46b4-92e6-1cb28f476107:16464, 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242 from path 0
# INFO:services.synced_traversal_service:No next critical points found for this path, continuing
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing subpath: [('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16456', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246'), ('4:d56c147a-80b2-46b4-92e6-1cb28f476107:16464', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242')]
# INFO:reduction_strategy.corner_point_reduction_strategy:Processing segment between: (4:d56c147a-80b2-46b4-92e6-1cb28f476107:16456,4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246) and (4:d56c147a-80b2-46b4-92e6-1cb28f476107:16464,4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242)
# INFO:reduction_strategy.corner_point_reduction_strategy:Best path pair found with score 0.481
# INFO:reduction_strategy.corner_point_reduction_strategy:Corner points in subpath: concept=3, image=0
# WARNING:root:Preprocessing failed for concept 3_1: Concept has corner points but image does not.
# Traceback (most recent call last):
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/concept_minor_classifier.py", line 110, in check_single_concept
#     self.critical_point_preprocessor.preprocess_graphs(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 76, in preprocess_graphs
#     inference_graph, concept_graph = self._reduce_graphs_for_isomorphism(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 129, in _reduce_graphs_for_isomorphism
#     self.corner_point_reduction_strategy.reduce(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/reduction_strategy/corner_point_reduction_strategy.py", line 58, in reduce
#     image_graph, concept_graph = self._subpath_based_reduction(
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/reduction_strategy/corner_point_reduction_strategy.py", line 138, in _subpath_based_reduction
#     self._reduce_corner_points_in_subpath(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/reduction_strategy/corner_point_reduction_strategy.py", line 235, in _reduce_corner_points_in_subpath
#     raise ValueError("Concept has corner points but image does not.")
# ValueError: Concept has corner points but image does not.
# INFO:common.decorator:⏱ check_single_concept took 17.617 ms (avg of 1 run)
# INFO:root:Checking concept 6_1 for minor of image
# INFO:root:Concept 6_1 is too complex to be a minor of the image
# INFO:common.decorator:⏱ check_single_concept took 15.252 ms (avg of 1 run)
# INFO:root:Checking concept 9_2 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [-0.00666667  0.83666667]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16482', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16484', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16486', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16488']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:16482', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16484', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16486', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:16488']
# INFO:reduction_strategy.endpoint_strategy:Concept has no endpoints. Reducing all endpoints in image.
# INFO:reduction_strategy.endpoint_strategy:Removing 4 nodes from graph. Nodes: {'4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15250', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15247', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244'}
# INFO:reduction_strategy.endpoint_strategy:Graph after reduction: 5 nodes, 4 edges
# INFO:reduction_strategy.intersection_strategy:Removing IntersectionPoint label from 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243 with degree 2
# INFO:reduction_strategy.intersection_strategy:Adding CornerPoint label to 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243 with degree 2
# WARNING:root:Preprocessing failed for concept 9_2: Concept has intersection points but image does not.
# Traceback (most recent call last):
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/concept_minor_classifier.py", line 110, in check_single_concept
#     self.critical_point_preprocessor.preprocess_graphs(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 76, in preprocess_graphs
#     inference_graph, concept_graph = self._reduce_graphs_for_isomorphism(
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/services/pre_processing/critical_point_preprocessor.py", line 121, in _reduce_graphs_for_isomorphism
#     self.intersection_reduction_strategy.reduce(
#   File "/Users/mlapin/Development/personal/NaturalAGI/src/classification/reduction_strategy/intersection_strategy.py", line 50, in reduce
#     raise ValueError("Concept has intersection points but image does not.")
# ValueError: Concept has intersection points but image does not.
# INFO:common.decorator:⏱ check_single_concept took 11.513 ms (avg of 1 run)
# INFO:root:Checking concept 1_1 for minor of image
# INFO:root:Preprocessing image graph
# INFO:services.pre_processing.start_point_preprocessor:Preprocessing start point
# INFO:services.pre_processing.start_point_preprocessor:Centroid: [0.08       0.89333333]
# INFO:services.pre_processing.start_point_preprocessor:New start point: 4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246
# INFO:services.pre_processing.critical_point_preprocessor:Preprocessing graphs for critical point compatibility
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are not isomorphic, applying reductions...
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 1: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Initial critical graph 2: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:19653', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:19655', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:19657', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:19659']
# INFO:services.pre_processing.critical_point_preprocessor:Iteration 1 of 5
# INFO:services.pre_processing.critical_point_preprocessor:Inference critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:15242', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15243', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15244', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15245', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:15246']
# INFO:services.pre_processing.critical_point_preprocessor:Concept critical graph: ['4:d56c147a-80b2-46b4-92e6-1cb28f476107:19653', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:19655', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:19657', '4:d56c147a-80b2-46b4-92e6-1cb28f476107:19659']
# INFO:reduction_strategy.endpoint_strategy:Concept and image have the same number of endpoints. No reduction needed.
# INFO:reduction_strategy.intersection_strategy:Concept and image have the same number of intersection points. No reduction needed.
# INFO:reduction_strategy.corner_point_reduction_strategy:No corner points found in concept graph. Reducing all corner points in image graph.
# INFO:services.pre_processing.critical_point_preprocessor:Critical point graphs are isomorphic, stopping
# INFO:root:Comparing graph with concept 1_1 using Graph Edit Distance
# INFO:graph_similarity.graph_edit_distance_comparator:GED: 1.9590067302531071
# INFO:root:GED: 1.9590067302531071, max_possible_ged: 16, similarity: 0.88
# INFO:root:Similarity between image and concept 1_1: 0.88
# INFO:common.decorator:⏱ check_single_concept took 225.094 ms (avg of 1 run)
# INFO:root:Sequential classification completed. Processed 8 concepts
# INFO:root:Found 4 matching concepts out of 8 processed
# ClassificationResult(concept_id='1_1', is_minor=True, message='Similarity between image and concept 1_1: 0.88', similarity=0.88, concept_complexity=13, image_complexity=17)
# ClassificationResult(concept_id='7_1', is_minor=True, message='Similarity between image and concept 7_1: 0.86', similarity=0.86, concept_complexity=9, image_complexity=17)
# ClassificationResult(concept_id='1_3', is_minor=True, message='Similarity between image and concept 1_3: 0.77', similarity=0.77, concept_complexity=5, image_complexity=17)
# ClassificationResult(concept_id='2_1', is_minor=True, message='Similarity between image and concept 2_1: 0.76', similarity=0.76, concept_complexity=13, image_complexity=17)
