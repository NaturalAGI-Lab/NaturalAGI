# %% [markdown]
# # Classification testing notebook

# %% [markdown]
# ## Set up

# %%
import os
import logging
import matplotlib.pyplot as plt
import networkx as nx
from typing import Dict, List, Any
import sys
from dotenv import load_dotenv


sys.path.append(os.path.abspath(".."))


from classification.concept_minor_classifier import ConceptMinorClassifier
from common.params import ClassificationParams

load_dotenv()


# Configure logging
logging.basicConfig(level=logging.INFO, 
                   format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# %%
params = ClassificationParams(
    feature_weight=0.5,
    structural_weight=0.5,
    ged_timeout=0.5,
)

logging.info(f"Classification params: {params}")
logging.info(f"Neo4j DSN: {os.getenv('NEO4J_DSN')}")
logging.info(f"Neo4j User: {os.getenv('NEO4J_USER')}")
logging.info(f"Neo4j Pass: {os.getenv('NEO4J_PASSWORD')}")


graph_comparator = ConceptMinorClassifier(
    neo4j_dsn=os.getenv("NEO4J_DSN"),
    neo4j_user=os.getenv("NEO4J_USER"),
    neo4j_pass=os.getenv("NEO4J_PASSWORD"),
    max_workers=10,
    use_multithreading=False,
)
# Out:
# INFO:root:Classification params: ClassificationParams(feature_weight=0.5, structural_weight=0.5, ged_timeout=0.5)
# INFO:root:Neo4j DSN: bolt://localhost:7687
# INFO:root:Neo4j User: neo4j
# INFO:root:Neo4j Pass: 111122223333

# %%
image_id = "test"
results = graph_comparator.classify(image_id, params)
graph_comparator.close()
results
# Out:
# INFO:root:Classifying image test using concept minor approach
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 7, column: 16, offset: 271} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 11, column: 16, offset: 397} for query: '\n        MATCH (n {concept_id: $concept_id})\n        WHERE n:Point OR n:Vector\n        WITH n, labels(n) AS node_labels, properties(n) as node_props\n        OPTIONAL MATCH (n)-[r]-(m {concept_id: $concept_id})\n        WITH n, node_labels, r, m, node_props\n        RETURN id(n) AS node_id, \n               node_labels,\n               node_props,\n               type(r) AS rel_type, \n               id(m) AS target_id\n        '
# INFO:root:Scores for concept 3_1 and image test:
# Structural: 0.1579, Is Minor: False, Complexity: 37, Activation: 0.4105
# INFO:root:Scores for concept 2_1 and image test:
# Structural: 0.6364, Is Minor: False, Complexity: 21, Activation: 0.5740
# INFO:root:Scores for concept 1_1 and image test:
# Structural: 0.8000, Is Minor: False, Complexity: 9, Activation: 0.5600
# Adding node with props:  {'labels': {'StartPoint', 'Point'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['top', 'left'], 'cycle_count': 0, 'vectors_count': 7, 'contour_type': 'OPEN', 'image_id': 'test', 'id': 'b35be8d8-d13e-4d1e-9f53-c7e368ccd04d', 'normalized_x': -0.6, 'relative_distance': 0.6, 'normalized_y': -0.6, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 21.311762614085936, 'x': 20.45129806421293}
# Adding node with props:  {'labels': {'CornerPoint', 'Point'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['top', 'center_vertical'], 'cycle_count': 0, 'vectors_count': 7, 'contour_type': 'OPEN', 'angle': 250, 'image_id': 'test', 'id': '7a50111a-6581-4fc6-ac47-f5883e7843fe', 'normalized_x': 0.1, 'relative_distance': 0.3, 'normalized_y': -0.4, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 27.62028402908696, 'x': 53.80838470434333}
# Adding node with props:  {'labels': {'Point', 'IntersectionPoint'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['center_horizontal', 'center_vertical'], 'cycle_count': 0, 'is_quadrant_change': 1, 'vectors_count': 7, 'contour_type': 'OPEN', 'angle': 230, 'image_id': 'test', 'id': '65870557-a709-426a-9a8f-91d5ee92b17c', 'normalized_x': 0.1, 'relative_distance': 0.1, 'normalized_y': -0.1, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 46.803259595906006, 'x': 55.578604060053095}
# Adding node with props:  {'labels': {'Point'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'right'], 'cycle_count': 0, 'is_quadrant_change': 1, 'vectors_count': 7, 'contour_type': 'OPEN', 'angle': 240, 'image_id': 'test', 'id': 'c070d6fe-3096-41b8-85d8-4cf8484bc607', 'normalized_x': 0.5, 'relative_distance': 0.4, 'normalized_y': 0.3, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 66.55175716049432, 'x': 73.40666498674916}
# Adding node with props:  {'labels': {'Point'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'right'], 'cycle_count': 0, 'vectors_count': 7, 'contour_type': 'OPEN', 'angle': 240, 'image_id': 'test', 'id': 'de22de49-9d57-407f-954a-11bed76639d3', 'normalized_x': 0.4, 'relative_distance': 0.5, 'normalized_y': 0.6, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 80.09269982764773, 'x': 68.52869148148456}
# Adding node with props:  {'labels': {'Point'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'center_vertical'], 'cycle_count': 0, 'is_quadrant_change': 1, 'vectors_count': 7, 'contour_type': 'OPEN', 'angle': 230, 'image_id': 'test', 'id': 'c630e6b8-0f50-4e14-9f1b-7df202dcf050', 'normalized_x': 0.1, 'relative_distance': 0.5, 'normalized_y': 0.7, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 84.04416831634026, 'x': 52.98794311375342}
# Adding node with props:  {'labels': {'Point', 'EndPoint'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'left'], 'cycle_count': 0, 'vectors_count': 7, 'contour_type': 'OPEN', 'image_id': 'test', 'id': 'b6cc6fe7-095c-4698-9ecd-85850f363ce7', 'normalized_x': -0.3, 'relative_distance': 0.4, 'normalized_y': 0.4, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 71.10554340478933, 'x': 33.02172803022977}
# Adding node with props:  {'labels': {'Point', 'EndPoint'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['center_horizontal', 'left'], 'cycle_count': 0, 'vectors_count': 7, 'contour_type': 'OPEN', 'image_id': 'test', 'id': '8d70c70c-8ef2-4ee9-83b1-974d8e3a90f9', 'normalized_x': -0.4, 'relative_distance': 0.3, 'normalized_y': -0.1, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'quadrant_change_count': 3, 'y': 46.01054589743065, 'x': 31.843010589261034}
# Adding node with props:  {'labels': {'Vector', 'HorizontalVector'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['top', 'left'], 'cycle_count': 0, 'y1': 21.311762614085936, 'y2': 27.62028402908696, 'half_plane': 'right', 'vectors_count': 7, 'x2': 53.80838470434333, 'contour_type': 'OPEN', 'image_id': 'test', 'quadrant': 1, 'x1': 20.45129806421293, 'id': '7727c1b5-c3fa-42f2-b4b2-2050f189a17a', 'normalized_x': -0.3, 'relative_distance': 0.4, 'normalized_y': -0.5, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'length': 33.948382458678246, 'quadrant_change_count': 3, 'angle_with_ox': 10}
# Adding node with props:  {'labels': {'Vector', 'VerticalVector'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['top', 'center_vertical'], 'cycle_count': 0, 'y1': 27.62028402908696, 'y2': 46.803259595906006, 'half_plane': 'upper', 'vectors_count': 7, 'x2': 55.578604060053095, 'contour_type': 'OPEN', 'image_id': 'test', 'quadrant': 1, 'x1': 53.80838470434333, 'id': '1467a510-3811-4cb5-a7ca-5a5b0476b422', 'normalized_x': 0.1, 'relative_distance': 0.2, 'normalized_y': -0.3, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'length': 19.264480999095355, 'quadrant_change_count': 3, 'angle_with_ox': 80}
# Adding node with props:  {'labels': {'Vector', 'VerticalVector'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['center_horizontal', 'right'], 'cycle_count': 0, 'y1': 46.803259595906006, 'y2': 66.55175716049432, 'half_plane': 'upper', 'vectors_count': 7, 'x2': 73.40666498674916, 'contour_type': 'OPEN', 'image_id': 'test', 'quadrant': 1, 'x1': 55.578604060053095, 'id': '80ca71f5-5c14-4c34-83e1-fce0041c80ba', 'normalized_x': 0.3, 'relative_distance': 0.2, 'normalized_y': 0.1, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'length': 26.605317371994225, 'quadrant_change_count': 3, 'angle_with_ox': 50}
# Adding node with props:  {'labels': {'Vector', 'HorizontalVector'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['center_horizontal', 'center_vertical'], 'cycle_count': 0, 'y1': 46.803259595906006, 'y2': 46.01054589743065, 'half_plane': 'left', 'vectors_count': 7, 'x2': 31.843010589261034, 'contour_type': 'OPEN', 'image_id': 'test', 'quadrant': 3, 'x1': 55.578604060053095, 'id': '04a828fd-4350-493f-8e9e-454b714ebc00', 'normalized_x': -0.1, 'relative_distance': 0.1, 'normalized_y': -0.1, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'length': 23.74882717985158, 'quadrant_change_count': 3, 'angle_with_ox': 180}
# Adding node with props:  {'labels': {'Vector', 'VerticalVector'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'right'], 'cycle_count': 0, 'y1': 66.55175716049432, 'y2': 80.09269982764773, 'half_plane': 'upper', 'vectors_count': 7, 'x2': 68.52869148148456, 'contour_type': 'OPEN', 'image_id': 'test', 'quadrant': 2, 'x1': 73.40666498674916, 'id': '0fb5c53b-40e5-48d7-bdff-127796a3b518', 'normalized_x': 0.4, 'relative_distance': 0.4, 'normalized_y': 0.5, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'length': 14.392767413989546, 'quadrant_change_count': 3, 'angle_with_ox': 110}
# Adding node with props:  {'labels': {'Vector', 'HorizontalVector'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'right'], 'cycle_count': 0, 'y1': 80.09269982764773, 'y2': 84.04416831634026, 'half_plane': 'left', 'vectors_count': 7, 'x2': 52.98794311375342, 'contour_type': 'OPEN', 'image_id': 'test', 'quadrant': 2, 'x1': 68.52869148148456, 'id': 'fbf9d598-434b-4c18-a5c5-89dee2788788', 'normalized_x': 0.2, 'relative_distance': 0.5, 'normalized_y': 0.6, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'length': 16.035241284317117, 'quadrant_change_count': 3, 'angle_with_ox': 170}
# Adding node with props:  {'labels': {'Vector', 'HorizontalVector'}, 'session_id': 'test', 'endpoints_count': 2, 'segments': ['bottom', 'center_vertical'], 'cycle_count': 0, 'y1': 84.04416831634026, 'y2': 71.10554340478933, 'half_plane': 'left', 'vectors_count': 7, 'x2': 33.02172803022977, 'contour_type': 'OPEN', 'image_id': 'test', 'quadrant': 3, 'x1': 52.98794311375342, 'id': 'a4df3779-0aeb-47ba-a492-bb3b3cc2f885', 'normalized_x': -0.1, 'relative_distance': 0.4, 'normalized_y': 0.6, 'monotony': 'NON_MONOTONIC', 'intersection_points_count': 1, 'corner_points_count': 1, 'length': 23.7919683793362, 'quadrant_change_count': 3, 'angle_with_ox': 150}
# [{'concept_id': '2_1',
#   'concept_name': '2_1',
#   'session_id': '2_1',
#   'raw_structural_score': 0.6363636363636364,
#   'is_minor': False,
#   'mapping_size': 7,
#   'concept_size': 11,
#   'image_size': 15,
#   'comparison_message': 'Partial matching for concept 2_1 with 7/11 nodes matched (63.64%)',
#   'concept_complexity': 21,
#   'activation_level': 0.574025974025974,
#   'combined_score': 0.574025974025974},
#  {'concept_id': '1_1',
#   'concept_name': '1_1',
#   'session_id': '1_1',
#   'raw_structural_score': 0.8,
#   'is_minor': False,
#   'mapping_size': 4,
#   'concept_size': 5,
#   'image_size': 15,
#   'comparison_message': 'Partial matching for concept 1_1 with 4/5 nodes matched (80.00%)',
#   'concept_complexity': 9,
#   'activation_level': 0.5599999999999999,
#   'combined_score': 0.5599999999999999},
#  {'concept_id': '3_1',
#   'concept_name': '3_1',
#   'session_id': '3_1',
#   'raw_structural_score': 0.15789473684210525,
#   'is_minor': False,
#   'mapping_size': 3,
#   'concept_size': 19,
#   'image_size': 15,
#   'comparison_message': 'Partial matching for concept 3_1 with 3/19 nodes matched (15.79%)',
#   'concept_complexity': 37,
#   'activation_level': 0.41052631578947363,
#   'combined_score': 0.41052631578947363}]
