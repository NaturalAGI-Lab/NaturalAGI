# %%
import sys
import os
import matplotlib.pyplot as plt

# Add the parent directory to the path first
sys.path.append(os.path.abspath("../.."))

# Now import the modules
from concept_creator.graph_intersection_concept_service import GraphIntersectionConceptService
from concept_creator.visualization_helpers import ConceptVisualization

# %%
# Neo4j configuration
uri = "bolt://localhost:7687"
user = "neo4j"
password = "111122223333"

# %%
session_id = '2_2'
concept_name = session_id

# %%
visualization = ConceptVisualization(figsize=(15, 10))

# %%
graph_intersection_concept_service = GraphIntersectionConceptService(uri, user, password)
concept_graph = graph_intersection_concept_service.create_concept(session_id)
visualization.visualize_graph(concept_graph, title="Concept Graph")
plt.show()
# Out:
# INFO:root:Initializing ConceptCreationRepository
# INFO:root:Database connection established
# INFO:concept_creator.graph_intersection_concept_service:Creating concept for session 2_2 using graph intersection approach
# INFO:root:Getting image IDs for session 2_2
# INFO:concept_creator.graph_intersection_concept_service:Found 6 images for session 2_2
# INFO:concept_creator.graph_intersection_concept_service:Extracting graph for image 1/6
# ...
